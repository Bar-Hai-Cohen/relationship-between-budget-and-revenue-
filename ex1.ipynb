# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Read the data from the CSV file
movies_df = pd.read_csv('tmdb_5000_movies.csv')

# Extract relevant columns and filter rows based on conditions
df_relevant = movies_df[
    (movies_df['release_date'] > '1990-01-01') &
    (movies_df['budget'] > 0) &
    (movies_df['revenue'] > 0)
][['title', 'budget', 'revenue', 'popularity', 'release_date', 'runtime', 'vote_average', 'vote_count']].copy()

# Create a figure and a single axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting the relationship between budget and revenue on the specified axis (ax) with smaller dots
scatter = ax.scatter(df_relevant['budget'], df_relevant['revenue'], s=20)  # Adjust the 's' parameter for dot size
ax.set_title('Relationship between Budget and Revenue for Movies (After 1990)')
ax.set_xlabel('Budget')
ax.set_ylabel(
    'Revenue', 
    rotation=0, 
    ha='right', 
    ma='left'
)

# Finding the movie with the highest revenue
max_revenue_movie = df_relevant.loc[df_relevant['revenue'].idxmax()]

# Finding the movie with the highest budget
max_budget_movie = df_relevant.loc[df_relevant['budget'].idxmax()]

# Adding captions for the highest revenue and budget points
ax.annotate(f'Movie with the Highest Revenue:\n{max_revenue_movie["title"]}\nRevenue: {max_revenue_movie["revenue"]:,.0f}\nBudget: {max_revenue_movie["budget"]:,.0f}', 
             xy=(max_revenue_movie['budget'], max_revenue_movie['revenue']),
             xytext=(30, -30), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1),
             fontsize=10, color='blue', fontweight='bold')

ax.annotate(f'Movie with the Highest Budget:\n{max_budget_movie["title"]}\nRevenue: {max_budget_movie["revenue"]:,.0f}\nBudget: {max_budget_movie["budget"]:,.0f}', 
             xy=(max_budget_movie['budget'], max_budget_movie['revenue']),
             xytext=(30, 40), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1),
             fontsize=10, color='green', fontweight='bold')

# Set x-axis ticks with a range and format them with commas
x_tick_range = range(0, int(df_relevant['budget'].max()), int(df_relevant['budget'].max() / 3))
ax.xaxis.set_major_locator(mticker.FixedLocator(x_tick_range))
ax.get_xaxis().set_major_formatter(mticker.StrMethodFormatter("{x:,.0f}"))

# Set y-axis ticks with a range and format them with commas
y_tick_range = range(0, int(df_relevant['revenue'].max()), int(df_relevant['revenue'].max() / 3))
ax.yaxis.set_major_locator(mticker.FixedLocator(y_tick_range))
ax.get_yaxis().set_major_formatter(mticker.StrMethodFormatter("{x:,.0f}"))

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Read the data from the CSV file
movies_df = pd.read_csv('tmdb_5000_movies.csv')

# Extract relevant columns and filter rows based on conditions
df_relevant = movies_df[
    (movies_df['release_date'] > '1990-01-01') &
    (movies_df['budget'] > 0) &
    (movies_df['revenue'] > 0)
][['title', 'budget', 'revenue', 'popularity', 'release_date', 'runtime', 'vote_average', 'vote_count']].copy()

# Create a figure and a single axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting the relationship between budget and revenue on the specified axis (ax)
scatter = ax.scatter(df_relevant['budget'], df_relevant['revenue'])
ax.set_title('Relationship between Budget and Revenue for Movies (After 1990)')
ax.set_xlabel('Budget')
ax.set_ylabel(
    'Revenue', 
    rotation=0, # Rotate the label to 0 degrees for horizontal alignment
    ha='right', # `ha` is `horizontalalignment`; align the end of label text with Y-axis
    ma='left' # `ma` is `marginal alignment`; align the label text with the end of the axis
) 
# Finding the movie with the highest revenue
max_revenue_movie = df_relevant.loc[df_relevant['revenue'].idxmax()]

# Finding the movie with the highest budget
max_budget_movie = df_relevant.loc[df_relevant['budget'].idxmax()]

# Adding text labels for the movies with the highest revenue and budget
ax.annotate(f'Highest Revenue: {max_revenue_movie["title"]}', 
             xy=(max_revenue_movie['budget'], max_revenue_movie['revenue']),
             xytext=(20, -25), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1))

ax.annotate(f'{max_revenue_movie["revenue"]:,.0f}', 
             xy=(max_revenue_movie['budget'], max_revenue_movie['revenue']),
             xytext=(0, -15), textcoords='offset points', ha='center', va='bottom', fontsize=8)

ax.annotate(f'Highest Budget: {max_budget_movie["title"]}', 
             xy=(max_budget_movie['budget'], max_budget_movie['revenue']),
             xytext=(20, 25), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1))

ax.annotate(f'{max_budget_movie["budget"]:,.0f}', 
             xy=(max_budget_movie['budget'], max_budget_movie['revenue']),
             xytext=(0, -15), textcoords='offset points', ha='center', va='bottom', fontsize=8)

# Set x-axis ticks with a range and format them with commas
x_tick_range = range(0, int(df_relevant['budget'].max()), int(df_relevant['budget'].max() / 3))
ax.xaxis.set_major_locator(mticker.FixedLocator(x_tick_range))
ax.get_xaxis().set_major_formatter(mticker.StrMethodFormatter("{x:,.0f}"))

# Set y-axis ticks with a range and format them with commas
y_tick_range = range(0, int(df_relevant['revenue'].max()), int(df_relevant['revenue'].max() / 3))
ax.yaxis.set_major_locator(mticker.FixedLocator(y_tick_range))
ax.get_yaxis().set_major_formatter(mticker.StrMethodFormatter("{x:,.0f}"))

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Read the data from the CSV file
movies_df = pd.read_csv('tmdb_5000_movies.csv')

# Extract relevant columns and filter rows based on conditions
df_relevant = movies_df[
    (movies_df['release_date'] > '1990-01-01') &
    (movies_df['budget'] > 0) &
    (movies_df['revenue'] > 0)
][['title', 'budget', 'revenue', 'popularity', 'release_date', 'runtime', 'vote_average', 'vote_count']].copy()

# Create a figure and a single axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting the relationship between budget and revenue on the specified axis (ax)
scatter = ax.scatter(df_relevant['budget'], df_relevant['revenue'], color='blue')
ax.set_title('Relationship between Budget and Revenue for Movies (After 1990)')
ax.set_xlabel('Budget')
ax.set_ylabel(
    'Revenue', 
    rotation=0, # Rotate the label to 0 degrees for horizontal alignment
    ha='right', # `ha` is `horizontalalignment`; align the end of label text with Y-axis
    ma='left' # `ma` is `marginal alignment`; align the label text with the end of the axis
) 
# Finding the movie with the highest revenue
max_revenue_movie = df_relevant.loc[df_relevant['revenue'].idxmax()]

# Finding the movie with the highest budget
max_budget_movie = df_relevant.loc[df_relevant['budget'].idxmax()]

# Adding text labels for the movies with the highest revenue and budget
ax.annotate(f'Highest Revenue: {max_revenue_movie["title"]}', 
             xy=(max_revenue_movie['budget'], max_revenue_movie['revenue']),
             xytext=(20, -25), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1),
             fontsize=8, fontweight='bold', color='red')

ax.annotate(f'{max_revenue_movie["revenue"]:,.0f}', 
             xy=(max_revenue_movie['budget'], max_revenue_movie['revenue']),
             xytext=(0, -15), textcoords='offset points', ha='center', va='bottom', fontsize=8, fontweight='bold', color='red')

ax.annotate(f'Highest Budget: {max_budget_movie["title"]}', 
             xy=(max_budget_movie['budget'], max_budget_movie['revenue']),
             xytext=(20, 25), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1),
             fontsize=8, fontweight='bold', color='red')

ax.annotate(f'{max_budget_movie["budget"]:,.0f}', 
             xy=(max_budget_movie['budget'], max_budget_movie['revenue']),
             xytext=(0, -15), textcoords='offset points', ha='center', va='bottom', fontsize=8, fontweight='bold', color='red')

# Set x-axis ticks with a range and format them with commas
x_tick_range = range(0, int(df_relevant['budget'].max()), int(df_relevant['budget'].max() / 3))
ax.xaxis.set_major_locator(mticker.FixedLocator(x_tick_range))
ax.get_xaxis().set_major_formatter(mticker.StrMethodFormatter("{x:,.0f}"))

# Set y-axis ticks with a range and format them with commas
y_tick_range = range(0, int(df_relevant['revenue'].max()), int(df_relevant['revenue'].max() / 3))
ax.yaxis.set_major_locator(mticker.FixedLocator(y_tick_range))
ax.get_yaxis().set_major_formatter(mticker.StrMethodFormatter("{x:,.0f}"))

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Read the data from the CSV file
movies_df = pd.read_csv('tmdb_5000_movies.csv')

# Extract relevant columns and filter rows based on conditions
df_relevant = movies_df[
    (movies_df['release_date'] > '1990-01-01') &
    (movies_df['budget'] > 0) &
    (movies_df['revenue'] > 0)
][['title', 'budget', 'revenue', 'popularity', 'release_date', 'runtime', 'vote_average', 'vote_count']].copy()

# Create a figure and a single axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting the relationship between budget and revenue on the specified axis (ax)
scatter = ax.scatter(df_relevant['budget'], df_relevant['revenue'], color='skyblue', alpha=0.5, s=20)
ax.set_title('Relationship between Budget and Revenue for Movies (After 1990)')
ax.set_xlabel('Budget')
ax.set_ylabel(
    'Revenue', 
    rotation=0, # Rotate the label to 0 degrees for horizontal alignment
    ha='right', # `ha` is `horizontalalignment`; align the end of label text with Y-axis
    ma='left' # `ma` is `marginal alignment`; align the label text with the end of the axis
) 
# Finding the movie with the highest revenue
max_revenue_movie = df_relevant.loc[df_relevant['revenue'].idxmax()]

# Finding the movie with the highest budget
max_budget_movie = df_relevant.loc[df_relevant['budget'].idxmax()]

# Adding text labels for the movies with the highest revenue and budget
ax.annotate(f'Highest Revenue: {max_revenue_movie["title"]}', 
             xy=(max_revenue_movie['budget'], max_revenue_movie['revenue']),
             xytext=(20, -25), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1),
             fontsize=8, fontweight='bold', color='red')

ax.annotate(f'{max_revenue_movie["revenue"]:,.0f}', 
             xy=(max_revenue_movie['budget'], max_revenue_movie['revenue']),
             xytext=(0, -15), textcoords='offset points', ha='center', va='bottom', fontsize=8, fontweight='bold', color='red')

ax.annotate(f'Highest Budget: {max_budget_movie["title"]}', 
             xy=(max_budget_movie['budget'], max_budget_movie['revenue']),
             xytext=(20, 25), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1),
             fontsize=8, fontweight='bold', color='green')

ax.annotate(f'{max_budget_movie["budget"]:,.0f}', 
             xy=(max_budget_movie['budget'], max_budget_movie['revenue']),
             xytext=(0, -15), textcoords='offset points', ha='center', va='bottom', fontsize=8, fontweight='bold', color='green')

# Set x-axis ticks with a range and format them with commas
x_tick_range = range(0, int(df_relevant['budget'].max()), int(df_relevant['budget'].max() / 3))
ax.xaxis.set_major_locator(mticker.FixedLocator(x_tick_range))
ax.get_xaxis().set_major_formatter(mticker.StrMethodFormatter("{x:,.0f}"))

# Set y-axis ticks with a range and format them with commas
y_tick_range = range(0, int(df_relevant['revenue'].max()), int(df_relevant['revenue'].max() / 3))
ax.yaxis.set_major_locator(mticker.FixedLocator(y_tick_range))
ax.get_yaxis().set_major_formatter(mticker.StrMethodFormatter("{x:,.0f}"))

# Show the plot
plt.show()

# %% [markdown]
# """
# about the title:
# 1."Budget vs. Revenue: Exploring the Financial Dynamics of Movies (After 1990)"
#
# 2."The Financial Dance: Budget and Revenue Analysis in Movies (1990 Onward)"
#
# 3."Show Me the Money: Unraveling the Budget-Revenue Relationship in Modern Cinema"
#
# 4."Behind the Scenes: Decoding the Budget-Revenue Dynamics in Post-1990 Movies"
#
# 5."Money Talks: A Deep Dive into Movie Budgets and Revenues (1990 Onward)"
#
# 6."Silver Screen Finances: Navigating the Budget and Revenue Landscape (After 1990)"
#
# """
